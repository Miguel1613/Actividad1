# %%
import statsmodels.api as sm
import pandas as pa
import numpy as np
TRAIN = pa.read_csv(r"C:\Users\Miguel Sarmiento\Documents\Cursos\curso phyton\train.csv")

# %%
TRAIN
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
### Al no encontrar datos faltantes en variables numericas no se hace necesario hacer limpieza de datos ###

# %%
X = TRAIN[["GarageArea","LotArea","PoolArea","1stFlrSF","2ndFlrSF","TotalBsmtSF"]]

# %%
Y = TRAIN['SalePrice']

# %%
X = sm.add_constant(X) 

model = sm.OLS(Y, X).fit()

predictions = model.predict(X) 

 

print_model = model.summary()

print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     487.0
# Date:                Tue, 16 Feb 2021   Prob (F-statistic):               0.00
# Time:                        11:08:03   Log-Likelihood:                -17739.
# No. Observations:                1460   AIC:                         3.549e+04
# Df Residuals:                    1453   BIC:                         3.553e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -2.407e+04   4257.571     -5.654      0.000   -3.24e+04   -1.57e+04
# ...

# %%
##Actividad Desarrollada por Miguel Angel Sarmiento Acosta correo miguel.sarmiento@bpsconsultores.com##
